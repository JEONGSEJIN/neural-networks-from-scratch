# %%
import numpy as np
inputs = [[1,2,3,2.5], [2.,5.,-1,2], [-1.5,2.7,3.3,-0.8]]
weights = [[0.2,0.8,-0.5,1], [0.5,-0.91,0.26,-0.5], [-0.26,-0.27,0.17,0.87]]
biases = [2,3,0.5]
weights2 = [[0.1,-0.14,0.5], [-0.5,0.12,-0.33], [-0.44,0.73,-0.13]]
biases2 = [-1,2,-0.5]
layer1_outputs = np.dot(inputs, np.array(weights).T) + biases
layer2_outputs = np.dot(layer1_outputs, np.array(weights2).T) + biases2
print("layer_1_output: ", layer1_outputs)
print("layer_2_output: ", layer2_outputs)
# Out:
# layer_1_output:  [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]
# layer_2_output:  [[ 0.5031  -1.04185 -2.03875]
#  [ 0.2434  -2.7332  -5.7633 ]
#  [-0.99314  1.41254 -0.35655]]

# %%
# !pip install nnfs

from nnfs.datasets import spiral_data
import numpy as np
import nnfs

nnfs.init()
# Out:
# Collecting nnfs
#   Downloading nnfs-0.5.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in c:\users\luytt\appdata\local\programs\python\python39\lib\site-packages (from nnfs) (1.25.2)
# Downloading nnfs-0.5.1-py3-none-any.whl (9.1 kB)
# Installing collected packages: nnfs
# Successfully installed nnfs-0.5.1
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\luytt\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\luytt\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\luytt\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\luytt\appdata\local\programs\python\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
X, y = spiral_data(samples = 100, classes = 3)
plt.scatter(X[:, 0], X[:, 1])
plt.title('Uncolored spiral dataset')
plt.show()
plt.scatter(X[:, 0], X[:, 1], c = y, cmap = 'brg')
plt.title('Spiral dataset colored by class')
plt.show()

# %%
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases

# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()

class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases

X, y = spiral_data(samples=100, classes=3)
dense1 = Layer_Dense(2,3)
dense1.forward(X)
print(dense1.output[:3])
# Out:
# [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [-1.0475188e-04  1.1395361e-04 -4.7983500e-05]
#  [-2.7414842e-04  3.1729150e-04 -8.6921798e-05]]
